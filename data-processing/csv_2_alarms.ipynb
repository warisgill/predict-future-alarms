# %%
import json
import pandas as pd
from datetime import datetime, timedelta
from dateutil.parser import parse
from pathlib import Path
import glob

# %%
# format csvs

class CSV2Alarms:
    """
        Summary:
        Record mean 1 row of the csv file. 
        This class converts records into alarms. 
    """
    def __init__(self,config):
        self.config = config
        print(f'>>Input file: {self.config["dir"]+self.config["in_fname"]}')
        self.df = pd.read_csv(self.config["dir"]+self.config["in_fname"], usecols=self.config["cols"], delimiter= "," ,encoding = "ISO-8859-1")
        # self.df.columns = [''.join(e for e in col if e.isalnum()) for col in self.df.columns]
        # self.df.columns = [col.replace("ï","") for col in self.df.columns]
        
    def __changeDate(self,d):
        d = d.replace(".000000000","")
        d = d.replace("/","-")
        return parse(d)

    def __getMessageType(self,message):
        if message.find("Recover") != -1:
            return "Recover"
        elif message.find("NR") != -1:
            return "NR"
        else:
            return "Activation"
    
    def __getAlarmsFromDFs(self,df_start, df_end):
        alarms = []
        start_records = [v for v in sorted(df_start.to_dict(
            orient="records"), key=lambda arg: arg["EventTime"], reverse=False)]
        end_records = [v for v in sorted(df_end.to_dict(
            orient="records"), key=lambda arg: arg["EventTime"], reverse=False)]
        i = 0
        j = 0
        # print("End len",len(end_records), "Start len", len(start_records))
        while j < len(end_records):
            # print(i,j)
            if len(start_records)>0 and end_records[j]["EventTime"] < start_records[i]["EventTime"]:
                j += 1
            else:
                break

        while i < len(start_records):
            
            if j <len(end_records) and start_records[i]["EventTime"] <= end_records[j]["EventTime"]:
                if i+1 < len(start_records) and start_records[i+1]["EventTime"] < end_records[j]["EventTime"]: # check for the next record
                    i += 1
                    continue
                alarm = {k: v for k, v in start_records[i].items()}
                alarm["StartTime"] = alarm["EventTime"]
                alarm["EndTime"] = end_records[j]["EventTime"]
                alarm["EndMessage"] = end_records[j]["Message"]
                del alarm["EventTime"]
                alarms.append(alarm)
                j += 1
            elif j <len(end_records) and start_records[i]["EventTime"] > end_records[j]["EventTime"]:
                j +=1
                continue   
                
            i += 1

        return alarms
    
    def __convertRecordsToAlarmsV1(self,df_source):
        alarms = []
        for condition in df_source["Condition"].unique():
            df_condition = df_source.loc[df_source['Condition'].isin([condition])]
            df_start = df_condition.loc[df_condition['MessageType'].isin([
                                                                        "Activation"])]
            end_types = [t for t in df_condition["MessageType"].unique() if t !=
                    "Activation"]
            # print(types)
            df_end = df_condition.loc[df_condition['MessageType'].isin(end_types)]
            alarms += self.__getAlarmsFromDFs(df_start, df_end)
        return alarms
    
    def __convertRecordsToAlarmsOld(self,records):
        """ Convert records from the same source to proper alarms with start and end time.   

            The record which contains "Recover" or "NR" in the Message column shows the deactivations. 

        Parameters
        ----------
        records : list of dict
            Each dict represent either activation of an alarm or deactivation of an alarm.  

        Returns
        -------
        alarms : list of dict
            Each dict in the list is an alarm with the StartTime and EndTime of an alarm. 
        """
        alarms = []  # conainsts alarms with start and end time.
        # for enqueue and deque of records., Needed dictionary because there can be multiple types of alarms from the same source.
        conditions_queues = {}
        alarm = None  # dictionary
        records = [v for v in sorted(
            records, key=lambda arg: arg["EventTime"], reverse=False)]
        for record in records:

            # initiazlize the queue
            if conditions_queues.get(record["Condition"]) == None:
                conditions_queues[record["Condition"]] = []

            # Enqueue the record
            if record["Message"].find("Recover") == -1 and record["Message"].find("NR") == -1:
                conditions_queues[record["Condition"]].append(record)
            else:
                if len(conditions_queues[record["Condition"]]) == 0:
                    continue

                alarm = conditions_queues[record["Condition"]].pop(
                    0)  # Dqueue the record
                alarm = {k: v for k, v in alarm.items()}
                alarm["StartTime"] = alarm["EventTime"]
                alarm["EndTime"] = record["EventTime"]
                alarm["EndMessage"] = record["Message"]
                del alarm["EventTime"]
                alarms.append(alarm)

        return alarms
    
    def formatCSV(self):
        print(">>Column  Types: ", end="")
        for col in self.df.columns:
            print(col, type(self.df[col][0]), end=", ")
            if isinstance(self.df[col][0],str):
                try:
                    self.df[col] = self.df[col].apply(lambda s: " ".join(s.split()))
                except Exception as e:
                    print(f"\n\n !!!!!!!!!!!!!!!!!! Excetpion {e} !!!!!!!!!!!!!!!!!!!!!!!!!!")

        print(type(self.df["EventTime"][0]))
        self.df["EventTime"] = self.df["EventTime"].apply(self.__changeDate)
        self.df["MessageType"] = self.df["Message"].apply(self.__getMessageType)
        # self.df["Month"] = self.df["EventTime"].apply(lambda arg: arg.month)
        print(f">>Before Filtering ACKS: {self.df.shape}")
        self.df = self.df.loc[self.df['Message'].map(lambda arg: arg.find(self.config["ack-filter"])) == -1] 
        print(f">>After Filtering ACKS: {self.df.shape}") 
        

        fpath = self.config["dir"] + self.config["formated_fname"]
        
        self.df.to_csv(fpath, index=False)
        self.df = pd.read_csv(fpath, low_memory=False, parse_dates=["EventTime"])
        print(f">> Formating is complete. Outfile: {fpath}")
        return self.df

    def convertRecords2Alarms(self,df):
        # df = pd.read_csv(p, low_memory=False, usecols=cols,parse_dates=["EventTime"])

        assert len(df["MachineName"].unique()) == 1 # all the alarms should be related to the same unit
        
        alarms = []
        differs = []
        sources_ranks_dict = df['SourceName'].value_counts()
        id = 0 # for debugging
        for sname in sources_ranks_dict.keys():
            id += 1
            df_sname = df.loc[df['SourceName'].isin([sname])] # source DF
            types_rank_dict = df_sname["MessageType"].value_counts() # source ranks
            total = 0
            for key in types_rank_dict.keys():
                total += types_rank_dict[key]
            assert(total== sources_ranks_dict[sname]) # sum is equal to count 
            
            source_alarms = self.__convertRecordsToAlarmsV1(df_sname)
            alarms += source_alarms
        
            print(f"[{id}]Source:{sname}, Conditions:{df_sname['Condition'].unique()}, Total Alarms:{len(source_alarms)}")

        ##comparing it with older algo
            # temp_alarms2 = self.__convertRecordsToAlarmsOld(df_sname.to_dict(orient="records"))
            # if len(source_alarms)-len(temp_alarms2) != 0:
            #     print(">>[{}]Source: {},Conditions:{}".format(id,sname, df_sname["Condition"].unique()), end="=>")
            #     print("ALARMS1:{},Alarms2:{},Diff(new-old):{}".format(len(source_alarms),len(temp_alarms2), len(source_alarms)-len(temp_alarms2)),end="")
            #     print("")

        
            # if (len(source_alarms) != len(temp_alarms2)):
            #     differs.append(sname)
        

        # print(">> Difference in 2 Algos",differs,len(differs))

        # writing to ouptut alarms
        df_out = pd.DataFrame(alarms)
        df_out["TimeDelta"] = df_out[["StartTime", "EndTime"]].apply(lambda arg: timedelta.total_seconds(arg[1]-arg[0]) , axis=1)
        df_out["Year-Month"] =df_out["StartTime"].apply(lambda arg: (arg.year,arg.month))

        file_path = self.config["dir"]+self.config["alarm_out_fname"] 
        df_out.to_csv(file_path, index = False)
        print(f">>Conversion from records to alarms is complete. Outputfile : {fiel_path}, Info : {df_out.info()}")
        return df_out

# %%
ACK_FILTER = "ACK"
config = {
    "dir": "../.data/csvs/",
    "in_fname": "raw/processed_2018.csv",
    "formated_fname": "raw/formatted_"+ "processed_2018.csv",
    "alarm_out_fname": "alarms/alarms_"+"processed_2018.csv",
    "ack-filter":ACK_FILTER,
    'cols':["MachineName","SourceName","EventTime", "Message","Condition"]

}
alarm  = CSV2Alarms(config)
df = alarm.formatCSV()
# df = alarm.
# Out:
# >>Input file: ../.data/csvs/raw/processed_2018.csv
# >>Column  Types: MachineName <class 'str'>, SourceName <class 'str'>, EventTime <class 'str'>, Message <class 'str'>, Condition <class 'str'>, <class 'str'>
# >>Before Filtering ACKS: (8636603, 7)
# >>After Filtering ACKS: (8525505, 7)
# >> Formating is complete. Outfile: ../.data/csvs/raw/formatted_processed_2018.csv

# %%
df2 = df

# %%
alarm2 = CSV2Alarms(config)
df_alarms = alarm2.convertRecords2Alarms(df2)
df_alarms
# Out:
# I'], Total Alarms:1
# [3980]Source:47BA1501F-ANN, Conditions:['ALM'], Total Alarms:0
# [3981]Source:47TI948K-BYP, Conditions:['OVR'], Total Alarms:1
# [3982]Source:47VSHH601-BYP, Conditions:['PWON'], Total Alarms:1
# [3983]Source:47TSHH720D-BYP, Conditions:['PWON'], Total Alarms:1
# [3984]Source:47TI938D-BYP, Conditions:['OVR'], Total Alarms:1
# [3985]Source:47PSL850-BYP, Conditions:['PWON'], Total Alarms:1
# [3986]Source:48PALL2004-ANN, Conditions:['ALM'], Total Alarms:0
# [3987]Source:47TI2080B-BYP, Conditions:['OVR'], Total Alarms:1
# [3988]Source:47TI1576, Conditions:['IOP'], Total Alarms:1
# [3989]Source:47BA1501G-ANN, Conditions:['ALM'], Total Alarms:0
# [3990]Source:01UA003-ANN, Conditions:['ALM'], Total Alarms:0
# [3991]Source:47ZAHH500-ANN, Conditions:['ALM'], Total Alarms:0
# [3992]Source:47XA035-ANN, Conditions:['ALM'], Total Alarms:0
# [3993]Source:47BA001B-ANN, Conditions:['ALM'], Total Alarms:0
# [3994]Source:47TI1550, Conditions:['IOP'], Total Alarms:1
# [3995]Source:47HSD-057HH-ANN, Conditions:['ALM'], Total Alarms:1
# [3996]Source:47TSHH422-BYP, Conditions:['PWON'], Total Alarms:1
# [3997]Source:AN-RX_FRAC_CNTRL, Conditions:['ALM'], Total Alarms:0
# [3998]Source:47SSLL002A-BYP, Conditions:['PWON'], Total Alarms:1
# [3999]Source:47TI803C, Conditions:['LO'], Total Alarms:0
# [4000]Source:47G2BCND05, Conditions:['ALM'], Total Alarms:1
# [4001]Source:47HA2101-ANN, Conditions:['ALM'], Total Alarms:0
# [4002]Source:47HID-016H-ANN, Conditions:['ALM'], Total Alarms:1
# [4003]Source:47TDI1548ADD, Conditions:['IOP'], Total Alarms:1
# [4004]Source:47FD-072HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4005]Source:47F201CND10, Conditions:['ALM'], Total Alarms:1
# [4006]Source:47_PF_MSINCR, Conditions:['IOP'], Total Alarms:1
# [4007]Source:47VSHH907-BYP, Conditions:['PWON'], Total Alarms:1
# [4008]Source:47TSHH487A-BYP, Conditions:['PWON'], Total Alarms:1
# [4009]Source:47TSHH424-BYP, Conditions:['PWON'], Total Alarms:1
# [4010]Source:47TI902-2, Conditions:['IOP'], Total Alarms:1
# [4011]Source:47FIC2003, Conditions:['OOP'], Total Alarms:1
# [4012]Source:47TSHH487B-BYP, Conditions:['PWON'], Total Alarms:1
# [4013]Source:47TI855-2, Conditions:['IOP'], Total Alarms:1
# [4014]Source:47_PF_47KM2B, Conditions:['IOP'], Total Alarms:0
# [4015]Source:47HCD-027H-ANN, Conditions:['ALM'], Total Alarms:1
# [4016]Source:47TX1705, Conditions:['IOP'], Total Alarms:1
# [4017]Source:47VAHH603-ANN, Conditions:['ALM'], Total Alarms:1
# [4018]Source:47TI926C, Conditions:['LO'], Total Alarms:1
# [4019]Source:47ZAH1801-ANN, Conditions:['ALM'], Total Alarms:0
# [4020]Source:48HSD-003HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4021]Source:47VAHH856-ANN, Conditions:['ALM'], Total Alarms:1
# [4022]Source:AN-F101_RQ_OFF, Conditions:['ALM'], Total Alarms:0
# [4023]Source:01UA007-ANN, Conditions:['ALM'], Total Alarms:0
# [4024]Source:47ZSHH601-BYP, Conditions:['PWON'], Total Alarms:1
# [4025]Source:47FD-039HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4026]Source:47TI015C-BYP, Conditions:['OVR'], Total Alarms:1
# [4027]Source:47TSHH770E-BYP, Conditions:['PWON'], Total Alarms:1
# [4028]Source:47FI3101, Conditions:['HI'], Total Alarms:1
# [4029]Source:47TSL002AB-BYP, Conditions:['PWON'], Total Alarms:1
# [4030]Source:47LI2019C-BYP, Conditions:['OVR'], Total Alarms:1
# [4031]Source:48BSL007-BYP, Conditions:['PWON'], Total Alarms:1
# [4032]Source:47FD-071H-ANN, Conditions:['ALM'], Total Alarms:1
# [4033]Source:47_AMPC_MSINCR, Conditions:['IOP'], Total Alarms:1
# [4034]Source:47BA1501B-ANN, Conditions:['ALM'], Total Alarms:0
# [4035]Source:47TI948G-BYP, Conditions:['OVR'], Total Alarms:1
# [4036]Source:47XA2028-ANN, Conditions:['ALM'], Total Alarms:0
# [4037]Source:47TXI341, Conditions:['LO' 'IOP'], Total Alarms:0
# [4038]Source:47HSD-025H-ANN, Conditions:['ALM'], Total Alarms:1
# [4039]Source:47PI752, Conditions:['IOP-'], Total Alarms:1
# [4040]Source:47FD-067HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4041]Source:47TSHH803A-BYP, Conditions:['PWON'], Total Alarms:1
# [4042]Source:47VAHH861-ANN, Conditions:['ALM'], Total Alarms:1
# [4043]Source:47TSHH432A-BYP, Conditions:['PWON'], Total Alarms:1
# [4044]Source:47TSHH803D-BYP, Conditions:['PWON'], Total Alarms:1
# [4045]Source:47VAHH600-ANN, Conditions:['ALM'], Total Alarms:1
# [4046]Source:47TI1706, Conditions:['IOP'], Total Alarms:1
# [4047]Source:01UA001-ANN, Conditions:['ALM'], Total Alarms:0
# [4048]Source:47LSLL2014-BYP, Conditions:['PWON'], Total Alarms:1
# [4049]Source:47_AMPA_9KM601B, Conditions:['IOP'], Total Alarms:1
# [4050]Source:47TSHH753C-BYP, Conditions:['PWON'], Total Alarms:1
# [4051]Source:47TI931B, Conditions:['HI'], Total Alarms:1
# [4052]Source:47TI937A-BYP, Conditions:['OVR'], Total Alarms:1
# [4053]Source:47TI921A2-BYP, Conditions:['OVR'], Total Alarms:1
# [4054]Source:47TI935B-BYP, Conditions:['OVR'], Total Alarms:1
# [4055]Source:47FD-073HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4056]Source:47TI938J-BYP, Conditions:['OVR'], Total Alarms:1
# [4057]Source:01UA005-ANN, Conditions:['ALM'], Total Alarms:0
# [4058]Source:47TXI147, Conditions:['LO' 'IOP'], Total Alarms:0
# [4059]Source:47TI935F-BYP, Conditions:['OVR'], Total Alarms:1
# [4060]Source:47HCD-002H-ANN, Conditions:['ALM'], Total Alarms:1
# [4061]Source:47TI1702, Conditions:['IOP'], Total Alarms:1
# [4062]Source:47TI803A, Conditions:['LO'], Total Alarms:0
# [4063]Source:47TI1515, Conditions:['IOP'], Total Alarms:1
# [4064]Source:47TI948B-BYP, Conditions:['OVR'], Total Alarms:1
# [4065]Source:47ZSHH868-BYP, Conditions:['PWON'], Total Alarms:1
# [4066]Source:47VSHH602-BYP, Conditions:['PWON'], Total Alarms:1
# [4067]Source:47TI920C-BYP, Conditions:['OVR'], Total Alarms:1
# [4068]Source:47HSD-006H-ANN, Conditions:['ALM'], Total Alarms:1
# [4069]Source:47HID-018HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4070]Source:47TI753A-2, Conditions:['IOP'], Total Alarms:1
# [4071]Source:47FD-074HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4072]Source:47LAL801-ANN, Conditions:['ALM'], Total Alarms:1
# [4073]Source:47VAHH909-ANN, Conditions:['ALM'], Total Alarms:1
# [4074]Source:48TI033A, Conditions:['IOP'], Total Alarms:1
# [4075]Source:47TI948L-BYP, Conditions:['OVR'], Total Alarms:1
# [4076]Source:47TI1575, Conditions:['IOP'], Total Alarms:1
# [4077]Source:47F201CND02, Conditions:['ALM'], Total Alarms:1
# [4078]Source:47FIX2024, Conditions:['IOP-'], Total Alarms:1
# [4079]Source:47TI015B-BYP, Conditions:['OVR'], Total Alarms:1
# [4080]Source:47TSHH428-BYP, Conditions:['PWON'], Total Alarms:1
# [4081]Source:47VAHH862-ANN, Conditions:['ALM'], Total Alarms:1
# [4082]Source:48PI073, Conditions:['HI' 'HH'], Total Alarms:0
# [4083]Source:47TI938H-BYP, Conditions:['OVR'], Total Alarms:1
# [4084]Source:01UA006-ANN, Conditions:['ALM'], Total Alarms:0
# [4085]Source:47TI444, Conditions:['IOP'], Total Alarms:1
# [4086]Source:47_VOLA_MSINCR, Conditions:['IOP'], Total Alarms:1
# [4087]Source:47FI3017, Conditions:['IOP'], Total Alarms:1
# [4088]Source:47TI945C-BYP, Conditions:['OVR'], Total Alarms:1
# [4089]Source:47TI2112A-BYP, Conditions:['OVR'], Total Alarms:1
# [4090]Source:47PSHH636A-BYP, Conditions:['PWON'], Total Alarms:1
# [4091]Source:47VSHH861B-BYP, Conditions:['PWON'], Total Alarms:1
# [4092]Source:47BA001Q-ANN, Conditions:['ALM'], Total Alarms:0
# [4093]Source:47HX2015, Conditions:['IOP-'], Total Alarms:1
# [4094]Source:47TI1581, Conditions:['IOP'], Total Alarms:1
# [4095]Source:47HIC2003, Conditions:['OOP'], Total Alarms:1
# [4096]Source:47XL022-ANN, Conditions:['ALM'], Total Alarms:0
# [4097]Source:47VSHH871B-BYP, Conditions:['PWON'], Total Alarms:1
# [4098]Source:47TI1565, Conditions:['IOP'], Total Alarms:1
# [4099]Source:AN-STR_STBY, Conditions:['ALM'], Total Alarms:0
# [4100]Source:47ZSHH600-BYP, Conditions:['PWON'], Total Alarms:1
# [4101]Source:47_AMPB_9KM601B, Conditions:['IOP'], Total Alarms:1
# [4102]Source:47VAHH921-ANN, Conditions:['ALM'], Total Alarms:1
# [4103]Source:47TI947D-BYP, Conditions:['OVR'], Total Alarms:1
# [4104]Source:47ZSHH901B-BYP, Conditions:['PWON'], Total Alarms:1
# [4105]Source:47TI946C-BYP, Conditions:['OVR'], Total Alarms:1
# [4106]Source:47TAH800B-ANN, Conditions:['ALM'], Total Alarms:1
# [4107]Source:47TI1547, Conditions:['IOP'], Total Alarms:1
# [4108]Source:47FD-039H-ANN, Conditions:['ALM'], Total Alarms:1
# [4109]Source:48HSD-003H-ANN, Conditions:['ALM'], Total Alarms:1
# [4110]Source:47_VOLC_MSINCR, Conditions:['IOP'], Total Alarms:1
# [4111]Source:47BA001A-ANN, Conditions:['ALM'], Total Alarms:0
# [4112]Source:47ZSHH857B-BYP, Conditions:['PWON'], Total Alarms:1
# [4113]Source:47TSHH820D-BYP, Conditions:['PWON'], Total Alarms:1
# [4114]Source:48HSD-004H-ANN, Conditions:['ALM'], Total Alarms:1
# [4115]Source:47PSLL2006-BYP, Conditions:['PWON'], Total Alarms:1
# [4116]Source:47UA716-ANN, Conditions:['ALM'], Total Alarms:1
# [4117]Source:47FD-074H-ANN, Conditions:['ALM'], Total Alarms:1
# [4118]Source:47XL018B-ANN, Conditions:['ALM'], Total Alarms:0
# [4119]Source:47HCD-079H-ANN, Conditions:['ALM'], Total Alarms:1
# [4120]Source:47XA2027-ANN, Conditions:['ALM'], Total Alarms:0
# [4121]Source:47FD-022HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4122]Source:47TI925C, Conditions:['LO'], Total Alarms:1
# [4123]Source:47ZSHH901A-BYP, Conditions:['PWON'], Total Alarms:1
# [4124]Source:47HCD-001H-ANN, Conditions:['ALM'], Total Alarms:1
# [4125]Source:47F201CND04, Conditions:['ALM'], Total Alarms:1
# [4126]Source:47VSHH920-BYP, Conditions:['PWON'], Total Alarms:1
# [4127]Source:47VAH2002A-ANN, Conditions:['ALM'], Total Alarms:1
# [4128]Source:47TI938B-BYP, Conditions:['OVR'], Total Alarms:1
# [4129]Source:47TSHH803B-BYP, Conditions:['PWON'], Total Alarms:1
# [4130]Source:47HCD-002HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4131]Source:47TI921B2-BYP, Conditions:['OVR'], Total Alarms:1
# [4132]Source:47TXI179, Conditions:['LO' 'IOP'], Total Alarms:0
# [4133]Source:47TI871B2-BYP, Conditions:['OVR'], Total Alarms:1
# [4134]Source:01UA004-ANN, Conditions:['ALM'], Total Alarms:0
# [4135]Source:7FI219, Conditions:['IOP'], Total Alarms:1
# [4136]Source:47UA2011-ANN, Conditions:['ALM'], Total Alarms:1
# [4137]Source:47TI920E, Conditions:['IOP'], Total Alarms:1
# [4138]Source:47G22-ANN, Conditions:['ALM'], Total Alarms:0
# [4139]Source:47F1CND11, Conditions:['ALM'], Total Alarms:1
# [4140]Source:47TI1526, Conditions:['IOP'], Total Alarms:1
# [4141]Source:47BA001K-ANN, Conditions:['ALM'], Total Alarms:0
# [4142]Source:47TXI355, Conditions:['LO' 'IOP'], Total Alarms:0
# [4143]Source:47TSHH803C-BYP, Conditions:['PWON'], Total Alarms:1
# [4144]Source:47HCD-079HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4145]Source:47F1CND07, Conditions:['ALM'], Total Alarms:1
# [4146]Source:47TSHH770F-BYP, Conditions:['PWON'], Total Alarms:1
# [4147]Source:47VSHH603-BYP, Conditions:['PWON'], Total Alarms:1
# [4148]Source:47FD-068HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4149]Source:47TSHH426A-BYP, Conditions:['PWON'], Total Alarms:1
# [4150]Source:47VSHH862B-BYP, Conditions:['PWON'], Total Alarms:1
# [4151]Source:47TI937F-BYP, Conditions:['OVR'], Total Alarms:1
# [4152]Source:47TSHH770D-BYP, Conditions:['PWON'], Total Alarms:1
# [4153]Source:47TSHH753A-BYP, Conditions:['PWON'], Total Alarms:1
# [4154]Source:47_KW_PMCC1L, Conditions:['IOP'], Total Alarms:1
# [4155]Source:47HSD-025HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4156]Source:47LI026B-BYP, Conditions:['OVR'], Total Alarms:1
# [4157]Source:47VSHH600-BYP, Conditions:['PWON'], Total Alarms:1
# [4158]Source:48FSLL027AB-BYP, Conditions:['PWON'], Total Alarms:1
# [4159]Source:47TI936E-BYP, Conditions:['OVR'], Total Alarms:1
# [4160]Source:48BAL2001-ANN, Conditions:['ALM'], Total Alarms:0
# [4161]Source:47_AMPA_MSINCR, Conditions:['IOP'], Total Alarms:1
# [4162]Source:47FD-023HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4163]Source:47LI2019B-BYP, Conditions:['OVR'], Total Alarms:1
# [4164]Source:47PSHH636C-BYP, Conditions:['PWON'], Total Alarms:1
# [4165]Source:47TSHH721-2-BYP, Conditions:['PWON'], Total Alarms:1
# [4166]Source:47HX2016, Conditions:['IOP-'], Total Alarms:1
# [4167]Source:47VAH2003A-ANN, Conditions:['ALM'], Total Alarms:1
# [4168]Source:47TI948F-BYP, Conditions:['OVR'], Total Alarms:1
# [4169]Source:47_PF_9KM601B, Conditions:['IOP'], Total Alarms:1
# [4170]Source:48UA2001-ANN, Conditions:['ALM'], Total Alarms:0
# [4171]Source:47K1CND18, Conditions:['ALM'], Total Alarms:1
# [4172]Source:47FI2004C, Conditions:['IOP'], Total Alarms:1
# [4173]Source:47TI2080A-BYP, Conditions:['OVR'], Total Alarms:1
# [4174]Source:47TI870B-BYP, Conditions:['OVR'], Total Alarms:1
# [4175]Source:47TI938G-BYP, Conditions:['OVR'], Total Alarms:1
# [4176]Source:47TI948A-BYP, Conditions:['OVR'], Total Alarms:1
# [4177]Source:47FD-073H-ANN, Conditions:['ALM'], Total Alarms:1
# [4178]Source:47TI946K-BYP, Conditions:['OVR'], Total Alarms:1
# [4179]Source:47HCD-001HH-ANN, Conditions:['ALM'], Total Alarms:1
# [4180]Source:47ZSHH700-BYP, Conditions:['PWON'], Total Alarms:1
# [4181]Source:47FD-037H-ANN, Conditions:['ALM'], Total Alarms:1
# [4182]Source:47TI938A-BYP, Conditions:['OVR'], Total Alarms:1
# [4183]Source:47TXI350, Conditions:['LO' 'IOP'], Total Alarms:0
# [4184]Source:47PAH2054-ANN, Conditions:['ALM'], Total Alarms:1
# [4185]Source:47TI936K-BYP, Conditions:['OVR'], Total Alarms:1
# [4186]Source:47VSHH921-BYP, Conditions:['PWON'], Total Alarms:1
# [4187]Source:47VAHH908-ANN, Conditions:['ALM'], Total Alarms:1
# [4188]Source:47TXI326, Conditions:['LO'], Total Alarms:0
# [4189]Source:47TI2023, Conditions:['IOP'], Total Alarms:0
# [4190]Source:47_KW_47GM2A, Conditions:['IOP'], Total Alarms:0
# [4191]Source:47LI1554A-BYP, Conditions:['OVR'], Total Alarms:0
# [4192]Source:47TXI034, Conditions:['LO'], Total Alarms:0
# [4193]Source:47TXI071, Conditions:['LO'], Total Alarms:0
# [4194]Source:47TXI042, Conditions:['LO'], Total Alarms:0
# [4195]Source:47PALL2031-ANN, Conditions:['ALM'], Total Alarms:0
# [4196]Source:C6-CIDAR4, Conditions:['IOP'], Total Alarms:0
# [4197]Source:%AN0002S012501, Conditions:['ALM'], Total Alarms:0
# [4198]Source:47TAH916-ANN, Conditions:['ALM'], Total Alarms:0
# [4199]Source:47TI2024, Conditions:['IOP'], Total Alarms:0
# [4200]Source:47C5FUPCND22, Conditions:['ALM'], Total Alarms:0
# [4201]Source:47_KW_47KM2C, Conditions:['IOP'], Total Alarms:0
# [4202]Source:47_AMPSA_47GM2B, Conditions:['IOP'], Total Alarms:0
# [4203]Source:47_AMPSC_47GM2A, Conditions:['IOP'], Total Alarms:0
# [4204]Source:47TXI175, Conditions:['LO'], Total Alarms:0
# [4205]Source:47K2BCND05, Conditions:['ALM'], Total Alarms:0
# [4206]Source:%AN0030S082601, Conditions:['ALM'], Total Alarms:0
# [4207]Source:47TXI045, Conditions:['LO'], Total Alarms:0
# [4208]Source:47TXI070, Conditions:['LO'], Total Alarms:0
# [4209]Source:47_AMPSA_47GM2A, Conditions:['IOP'], Total Alarms:0
# [4210]Source:%AN0012S012501, Conditions:['ALM'], Total Alarms:0
# [4211]Source:47_AMPSC_47KM2A, Conditions:['IOP'], Total Alarms:0
# [4212]Source:%AN0093S082101, Conditions:['ALM'], Total Alarms:0
# [4213]Source:47PI1772, Conditions:['IOP-'], Total Alarms:0
# [4214]Source:47TI812, Conditions:['LO'], Total Alarms:0
# [4215]Source:47TI2007A-BYP, Conditions:['OVR'], Total Alarms:0
# [4216]Source:%AN0197S082001, Conditions:['ALM'], Total Alarms:0
# [4217]Source:47_PF_47GM2A, Conditions:['IOP'], Total Alarms:0
# [4218]Source:AN-NS_SUB_SMOC, Conditions:['ALM'], Total Alarms:0
# [4219]Source:%AN0185S082001, Conditions:['ALM'], Total Alarms:0
# [4220]Source:47CEMS-O2N, Conditions:['LO'], Total Alarms:0
# [4221]Source:%AN0010S012501, Conditions:['ALM'], Total Alarms:0
# [4222]Source:47TXI195, Conditions:['LO'], Total Alarms:0
# [4223]Source:47TXI197, Conditions:['LO'], Total Alarms:0
# [4224]Source:47TI712, Conditions:['LO'], Total Alarms:0
# [4225]Source:47TXI151, Conditions:['LO'], Total Alarms:0
# [4226]Source:47TXI069, Conditions:['LO'], Total Alarms:0
# [4227]Source:47TI2007C-BYP, Conditions:['OVR'], Total Alarms:0
# [4228]Source:47TXI043, Conditions:['LO'], Total Alarms:0
# [4229]Source:47TXI063, Conditions:['LO'], Total Alarms:0
# [4230]Source:47TI412C, Conditions:['IOP'], Total Alarms:0
# [4231]Source:48PI2003, Conditions:['IOP-'], Total Alarms:0
# [4232]Source:47_PF_47KM2A, Conditions:['IOP'], Total Alarms:0
# [4233]Source:47TXI040, Conditions:['LO'], Total Alarms:0
# [4234]Source:47TXI032, Conditions:['LO'], Total Alarms:0
# [4235]Source:47FIC1524X, Conditions:['OOP'], Total Alarms:0
# [4236]Source:47_AMPB_48KM1A, Conditions:['IOP'], Total Alarms:0
# [4237]Source:47TXI051, Conditions:['LO'], Total Alarms:0
# [4238]Source:47XL1569-ANN, Conditions:['ALM'], Total Alarms:0
# [4239]Source:47TI944-CAL1, Conditions:['IOP'], Total Alarms:0
# [4240]Source:47ZAL1516, Conditions:['ALM'], Total Alarms:0
# [4241]Source:47TAH608-ANN, Conditions:['ALM'], Total Alarms:0
# [4242]Source:47TXI052, Conditions:['LO'], Total Alarms:0
# [4243]Source:47TXI050, Conditions:['LO'], Total Alarms:0
# [4244]Source:47_AMPC_48KM1A, Conditions:['IOP'], Total Alarms:0
# [4245]Source:47VAH009-ANN, Conditions:['ALM'], Total Alarms:0
# [4246]Source:%AN0015S012501, Conditions:['ALM'], Total Alarms:0
# [4247]Source:47PX2023-1, Conditions:['OOP'], Total Alarms:0
# [4248]Source:%AN0217S082001, Conditions:['ALM'], Total Alarms:0
# [4249]Source:47_13_MOSPER, Conditions:['PWON'], Total Alarms:0
# [4250]Source:47TXI062, Conditions:['LO'], Total Alarms:0
# [4251]Source:47TXI348, Conditions:['LO'], Total Alarms:0
# [4252]Source:%AN0008S012501, Conditions:['ALM'], Total Alarms:0
# [4253]Source:47TXI059, Conditions:['LO'], Total Alarms:0
# [4254]Source:%AN0005S012501, Conditions:['ALM'], Total Alarms:0
# [4255]Source:AN-STR_COMM, Conditions:['ALM'], Total Alarms:0
# [4256]Source:%AN0006S012501, Conditions:['ALM'], Total Alarms:0
# [4257]Source:%AN0007S012501, Conditions:['ALM'], Total Alarms:0
# [4258]Source:47_AMPSB_47KM2A, Conditions:['IOP'], Total Alarms:0
# [4259]Source:47TXI044, Conditions:['LO'], Total Alarms:0
# [4260]Source:47TXI060, Conditions:['LO'], Total Alarms:0
# [4261]Source:47PI1773, Conditions:['IOP-'], Total Alarms:0
# [4262]Source:47TXI041, Conditions:['LO'], Total Alarms:0
# [4263]Source:%AN0003S012501, Conditions:['ALM'], Total Alarms:0
# [4264]Source:47_AMPSC_47GM2B, Conditions:['IOP'], Total Alarms:0
# [4265]Source:47TAH876-ANN, Conditions:['ALM'], Total Alarms:0
# [4266]Source:47TXI035, Conditions:['LO'], Total Alarms:0
# [4267]Source:47_AMPSB_47KM2C, Conditions:['IOP'], Total Alarms:0
# [4268]Source:C6-CIDAR9, Conditions:['IOP'], Total Alarms:0
# [4269]Source:47_AMPSA_47KM2A, Conditions:['IOP'], Total Alarms:0
# [4270]Source:%AN0142S082101, Conditions:['ALM'], Total Alarms:0
# [4271]Source:47PDAH854-ANN, Conditions:['ALM'], Total Alarms:0
# [4272]Source:%AN0153S082001, Conditions:['ALM'], Total Alarms:0
# [4273]Source:47_KW_47GM2B, Conditions:['IOP'], Total Alarms:0
# [4274]Source:47TXI053, Conditions:['LO'], Total Alarms:0
# [4275]Source:%AN0009S012501, Conditions:['ALM'], Total Alarms:0
# [4276]Source:47_AMPSC_47KM2C, Conditions:['IOP'], Total Alarms:0
# [4277]Source:47TXI039, Conditions:['LO'], Total Alarms:0
# [4278]Source:AN-RX_FRAC_COMM, Conditions:['ALM'], Total Alarms:0
# [4279]Source:47_PF_47GM2B, Conditions:['IOP'], Total Alarms:0
# [4280]Source:47_AMPSA_47KM2C, Conditions:['IOP'], Total Alarms:0
# [4281]Source:47_AMPSB_47GM2B, Conditions:['IOP'], Total Alarms:0
# [4282]Source:%AN0120S082101, Conditions:['ALM'], Total Alarms:0
# [4283]Source:47_AMPSB_47GM2A, Conditions:['IOP'], Total Alarms:0
# [4284]Source:47TI2028, Conditions:['IOP'], Total Alarms:0
# [4285]Source:47_KW_47KM2A, Conditions:['IOP'], Total Alarms:0
# [4286]Source:48TI037, Conditions:['LO'], Total Alarms:0
# [4287]Source:47PALL2036-ANN, Conditions:['ALM'], Total Alarms:0
# [4288]Source:47TXI033, Conditions:['LO'], Total Alarms:0
# [4289]Source:47TXI049, Conditions:['LO'], Total Alarms:0
# [4290]Source:47TSHH2108-BYP, Conditions:['PWON'], Total Alarms:0
# [4291]Source:47TI412, Conditions:['IOP'], Total Alarms:0
# [4292]Source:47_PF_47KM2C, Conditions:['IOP'], Total Alarms:0
# [4293]Source:%AN0237S082001, Conditions:['ALM'], Total Alarms:0
# [4294]Source:47TXI061, Conditions:['LO'], Total Alarms:0
# [4295]Source:47TXI054, Conditions:['LO'], Total Alarms:0
# [4296]Source:47_PF_48KM1A, Conditions:['IOP'], Total Alarms:0
# [4297]Source:47TXI160, Conditions:['LO'], Total Alarms:0
# [4298]Source:%AN0001S012501, Conditions:['ALM'], Total Alarms:0
# [4299]Source:47TI2007B-BYP, Conditions:['OVR'], Total Alarms:0
# [4300]Source:47K2CCND05, Conditions:['ALM'], Total Alarms:0
# [4301]Source:47_AMPA_48KM1A, Conditions:['IOP'], Total Alarms:0
# [4302]Source:%AN0022S082301, Conditions:['ALM'], Total Alarms:0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-587f8c9bc5cc> in <module>
#       1 alarm2 = CSV2Alarms(config)
# ----> 2 df_alarms = alarm2.convertRecords2Alarms(df2)
#       3 df_alarms
#
# <ipython-input-6-f9fd105f15e5> in convertRecords2Alarms(self, df)
#     187         # writing to ouptut alarms
#     188         df_out = pd.DataFrame(alarms)
# --> 189         df_out["TimeDelta"] = df_out[["StartTime", "EndTime"]].apply(lambda arg: timedelta.total_seconds(arg[1]-arg[0]) , axis=1)
#     190         df_out["Year-Month"] =df_out["StartTime"].apply(lambda arg: (arg.year,arg.month))
#     191
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-6-f9fd105f15e5> in <lambda>(arg)
#     187         # writing to ouptut alarms
#     188         df_out = pd.DataFrame(alarms)
# --> 189         df_out["TimeDelta"] = df_out[["StartTime", "EndTime"]].apply(lambda arg: timedelta.total_seconds(arg[1]-arg[0]) , axis=1)
#     190         df_out["Year-Month"] =df_out["StartTime"].apply(lambda arg: (arg.year,arg.month))
#     191
#
# NameError: name 'timedelta' is not defined
