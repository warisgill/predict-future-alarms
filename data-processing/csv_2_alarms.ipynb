# %%
import json
import pandas as pd
from datetime import datetime, timedelta
from dateutil.parser import parse
from pathlib import Path
import glob

# %%
# format csvs

class CSV2Alarms:
    """
        Summary:
        Record mean 1 row of the csv file. 
        This class converts records into alarms. 
    """
    def __init__(self,config):
        self.config = config
        print(f'>>Input file: {self.config["dir"]+self.config["in_fname"]}')
         
        self.df = None
        try:
            self.df = pd.read_csv(self.config["dir"]+self.config["in_fname"], delimiter= ";" , usecols=self.config["cols"], encoding = "ISO-8859-1")
        except Exception as e:
            # print(f"\n\n !!!!!!!!!!!!!!!!!! Excetpion 1  {e} !!!!!!!!!!!!!!!!!!!!!!!!!!")
            a = 1
        
        try:
            self.df = pd.read_csv(self.config["dir"]+self.config["in_fname"], delimiter= "," , usecols=self.config["cols"], encoding = "ISO-8859-1")
        except Exception as e:
            a =1
            # self.df = pd.read_csv(self.config["dir"]+self.config["in_fname"], encoding = "ISO-8859-1")
            # print(f"\n\n !!!!!!!!!!!!!!!!!! Excetpion 2 {e} !!!!!!!!!!!!!!!!!!!!!!!!!!")
        
        cols =self.df.columns.values.tolist()
        print(">>File is read.")
        
    def __changeDate(self,d):
        d = d.replace(".000000000","")
        d = d.replace("/","-")
        return parse(d)

    def __getMessageType(self,message):
        if message.find("Recover") != -1:
            return "Recover"
        elif message.find("NR") != -1:
            return "NR"
        else:
            return "Activation"
    
    def __getAlarmsFromDFs(self,df_start, df_end):
        alarms = []
        start_records = [v for v in sorted(df_start.to_dict(
            orient="records"), key=lambda arg: arg["EventTime"], reverse=False)]
        end_records = [v for v in sorted(df_end.to_dict(
            orient="records"), key=lambda arg: arg["EventTime"], reverse=False)]
        i = 0
        j = 0
        # print("End len",len(end_records), "Start len", len(start_records))
        while j < len(end_records):
            # print(i,j)
            if len(start_records)>0 and end_records[j]["EventTime"] < start_records[i]["EventTime"]:
                j += 1
            else:
                break

        while i < len(start_records):
            
            if j <len(end_records) and start_records[i]["EventTime"] <= end_records[j]["EventTime"]:
                if i+1 < len(start_records) and start_records[i+1]["EventTime"] < end_records[j]["EventTime"]: # check for the next record
                    i += 1
                    continue
                alarm = {k: v for k, v in start_records[i].items()}
                alarm["StartTime"] = alarm["EventTime"]
                alarm["EndTime"] = end_records[j]["EventTime"]
                alarm["EndMessage"] = end_records[j]["Message"]
                del alarm["EventTime"]
                alarms.append(alarm)
                j += 1
            elif j <len(end_records) and start_records[i]["EventTime"] > end_records[j]["EventTime"]:
                j +=1
                continue   
                
            i += 1

        return alarms
    
    def __convertRecordsToAlarmsV1(self,df_source):
        alarms = []
        for condition in df_source["Condition"].unique():
            df_condition = df_source.loc[df_source['Condition'].isin([condition])]
            df_start = df_condition.loc[df_condition['MessageType'].isin([
                                                                        "Activation"])]
            end_types = [t for t in df_condition["MessageType"].unique() if t !=
                    "Activation"]
            # print(types)
            df_end = df_condition.loc[df_condition['MessageType'].isin(end_types)]
            alarms += self.__getAlarmsFromDFs(df_start, df_end)
        return alarms
    
    def __convertRecordsToAlarmsOld(self,records):
        """ Convert records from the same source to proper alarms with start and end time.   

            The record which contains "Recover" or "NR" in the Message column shows the deactivations. 

        Parameters
        ----------
        records : list of dict
            Each dict represent either activation of an alarm or deactivation of an alarm.  

        Returns
        -------
        alarms : list of dict
            Each dict in the list is an alarm with the StartTime and EndTime of an alarm. 
        """
        alarms = []  # conainsts alarms with start and end time.
        # for enqueue and deque of records., Needed dictionary because there can be multiple types of alarms from the same source.
        conditions_queues = {}
        alarm = None  # dictionary
        records = [v for v in sorted(
            records, key=lambda arg: arg["EventTime"], reverse=False)]
        for record in records:

            # initiazlize the queue
            if conditions_queues.get(record["Condition"]) == None:
                conditions_queues[record["Condition"]] = []

            # Enqueue the record
            if record["Message"].find("Recover") == -1 and record["Message"].find("NR") == -1:
                conditions_queues[record["Condition"]].append(record)
            else:
                if len(conditions_queues[record["Condition"]]) == 0:
                    continue

                alarm = conditions_queues[record["Condition"]].pop(
                    0)  # Dqueue the record
                alarm = {k: v for k, v in alarm.items()}
                alarm["StartTime"] = alarm["EventTime"]
                alarm["EndTime"] = record["EventTime"]
                alarm["EndMessage"] = record["Message"]
                del alarm["EventTime"]
                alarms.append(alarm)

        return alarms
    
    def formatCSV(self):
        print(">>Column  Types: ", end="")
        for col in self.df.columns:
            print(col, type(self.df[col][0]), end=", ")
            if isinstance(self.df[col][0],str):
                try:
                    self.df[col] = self.df[col].apply(lambda s: " ".join(s.split()))
                except Exception as e:
                    print(f"\n\n !!!!!!!!!!!!!!!!!! Excetpion {e} !!!!!!!!!!!!!!!!!!!!!!!!!!")

        print(type(self.df["EventTime"][0]))
        self.df["EventTime"] = self.df["EventTime"].apply(self.__changeDate)
        self.df["MessageType"] = self.df["Message"].apply(self.__getMessageType)
        # self.df["Month"] = self.df["EventTime"].apply(lambda arg: arg.month)
        print(f">>Before Filtering ACKS: {self.df.shape}")
        self.df = self.df.loc[self.df['Message'].map(lambda arg: arg.find(self.config["ack-filter"])) == -1] 
        print(f">>After Filtering ACKS: {self.df.shape}") 
        

        fpath = self.config["dir"] + self.config["formated_fname"]
        
        self.df.to_csv(fpath, index=False)
        self.df = pd.read_csv(fpath, low_memory=False, parse_dates=["EventTime"])
        print(f">> Formating is complete. Outfile: {fpath}")
        return self.df

    def convertRecords2Alarms(self,df):
        # df = pd.read_csv(p, low_memory=False, usecols=cols,parse_dates=["EventTime"])

        assert len(df["MachineName"].unique()) == 1 # all the alarms should be related to the same unit
        
        alarms = []
        differs = []
        sources_ranks_dict = df['SourceName'].value_counts()
        id = 0 # for debugging
        for sname in sources_ranks_dict.keys():
            id += 1
            df_sname = df.loc[df['SourceName'].isin([sname])] # source DF
            types_rank_dict = df_sname["MessageType"].value_counts() # source ranks
            total = 0
            for key in types_rank_dict.keys():
                total += types_rank_dict[key]
            assert(total== sources_ranks_dict[sname]) # sum is equal to count 
            
            source_alarms = self.__convertRecordsToAlarmsV1(df_sname)
            alarms += source_alarms
        
            print(f"[{id}]Source:{sname}, Conditions:{df_sname['Condition'].unique()}, Total Alarms:{len(source_alarms)}")

        ##comparing it with older algo
            # temp_alarms2 = self.__convertRecordsToAlarmsOld(df_sname.to_dict(orient="records"))
            # if len(source_alarms)-len(temp_alarms2) != 0:
            #     print(">>[{}]Source: {},Conditions:{}".format(id,sname, df_sname["Condition"].unique()), end="=>")
            #     print("ALARMS1:{},Alarms2:{},Diff(new-old):{}".format(len(source_alarms),len(temp_alarms2), len(source_alarms)-len(temp_alarms2)),end="")
            #     print("")

        
            # if (len(source_alarms) != len(temp_alarms2)):
            #     differs.append(sname)
        

        # print(">> Difference in 2 Algos",differs,len(differs))

        # writing to ouptut alarms
        df_out = pd.DataFrame(alarms)
        df_out["TimeDelta"] = df_out[["StartTime", "EndTime"]].apply(lambda arg: timedelta.total_seconds(arg[1]-arg[0]) , axis=1)
        df_out["Year-Month"] =df_out["StartTime"].apply(lambda arg: (arg.year,arg.month))

        file_path = self.config["dir"]+self.config["alarm_out_fname"] 
        df_out.to_csv(file_path, index = False)
        print(f">>Conversion from records to alarms is complete. Outputfile : {file_path}, Info : {df_out.info()}")
        return df_out

# %%
ACK_FILTER = "ACK"
config = {
    "dir": "../.data/csvs/",
    # "in_fname": "raw/2019_5.csv",
    # "formated_fname": "raw/formatted_"+"2019_5.csv",
    # "alarm_out_fname": "alarms/alarms_"+"2019_5.csv",
    "ack-filter":ACK_FILTER,
    'cols':["MachineName","SourceName","EventTime", "Message","Condition"]

}

csv_names = [f.split('/')[-1] for f in glob.glob("../.data/csvs/raw/"+ "*.csv") if f.find("formatted")==-1]
alarm = None
temp_df = None
for f in csv_names:
    config['in_fname'] =  "raw/"+f
    config['formated_fname'] = "raw/formatted_"+f
    config["alarm_out_fname"] = "alarms/alarms_"+f
    alarm  = CSV2Alarms(config)
    temp_df = alarm.formatCSV()
    df_alarms = alarm.convertRecords2Alarms(temp_df)

print(">> Complete")
# Out:
# otal Alarms:4
# [392]Source:47TI703A-2, Conditions:['HTRP' 'HHH'], Total Alarms:4
# [393]Source:47TI2077, Conditions:['LL' 'LO'], Total Alarms:2
# [394]Source:47PI807ABC, Conditions:['LTRP' 'LLL'], Total Alarms:4
# [395]Source:47XL1553-ANN, Conditions:['ALM'], Total Alarms:3
# [396]Source:47TI609, Conditions:['HI'], Total Alarms:3
# [397]Source:47LAL701-ANN, Conditions:['ALM'], Total Alarms:3
# [398]Source:47XL1554-ANN, Conditions:['ALM'], Total Alarms:3
# [399]Source:47FI2002, Conditions:['LO'], Total Alarms:2
# [400]Source:47XL1538B-ANN, Conditions:['ALM'], Total Alarms:3
# [401]Source:47PALL707-ANN, Conditions:['ALM'], Total Alarms:3
# [402]Source:48TI018, Conditions:['HI' 'LL' 'LO'], Total Alarms:2
# [403]Source:47PAL708-ANN, Conditions:['ALM'], Total Alarms:3
# [404]Source:47TI1765, Conditions:['HI' 'HH'], Total Alarms:3
# [405]Source:47TI925B, Conditions:['HI' 'LO'], Total Alarms:2
# [406]Source:48FI020, Conditions:['LO' 'LL'], Total Alarms:2
# [407]Source:47C56SUM_DT, Conditions:['HI' 'HH'], Total Alarms:2
# [408]Source:47FI1503B, Conditions:['LLL'], Total Alarms:3
# [409]Source:47FI2031, Conditions:['HI'], Total Alarms:3
# [410]Source:47PI712, Conditions:['LTRP' 'LLL'], Total Alarms:2
# [411]Source:48TI030, Conditions:['LO' 'LL' 'HH' 'HI'], Total Alarms:2
# [412]Source:47PI700, Conditions:['LTRP' 'LLL'], Total Alarms:2
# [413]Source:47AI2014, Conditions:['IOP-'], Total Alarms:3
# [414]Source:48AAH008-ANN, Conditions:['ALM'], Total Alarms:3
# [415]Source:47LIC3205, Conditions:['HI' 'HH'], Total Alarms:3
# [416]Source:48TI022, Conditions:['LL' 'LO'], Total Alarms:2
# [417]Source:47TI856, Conditions:['HI'], Total Alarms:3
# [418]Source:47HCD-047H-ANN, Conditions:['ALM'], Total Alarms:3
# [419]Source:47TI1533, Conditions:['LO' 'LL'], Total Alarms:2
# [420]Source:47PDI1749, Conditions:['IOP'], Total Alarms:3
# [421]Source:47XL801-ANN, Conditions:['ALM'], Total Alarms:2
# [422]Source:47LI3104A, Conditions:['LTRP' 'LLL'], Total Alarms:3
# [423]Source:47TI852, Conditions:['HI'], Total Alarms:3
# [424]Source:48TI028, Conditions:['HH' 'HI' 'LL' 'LO'], Total Alarms:2
# [425]Source:47LI011, Conditions:['HI'], Total Alarms:3
# [426]Source:48HSD-001HH-ANN, Conditions:['ALM'], Total Alarms:3
# [427]Source:47XL3602-ANN, Conditions:['ALM'], Total Alarms:2
# [428]Source:47FI1503C, Conditions:['LLL'], Total Alarms:3
# [429]Source:47PI053A, Conditions:['HHH'], Total Alarms:3
# [430]Source:47XL1532-ANN, Conditions:['ALM'], Total Alarms:3
# [431]Source:47TX014, Conditions:['DV-' 'DV+'], Total Alarms:3
# [432]Source:47LIC1508, Conditions:['LO'], Total Alarms:3
# [433]Source:48TI027, Conditions:['LO' 'LL' 'HI' 'HH'], Total Alarms:2
# [434]Source:47TI414I, Conditions:['LO' 'LL'], Total Alarms:3
# [435]Source:47TI1509, Conditions:['HI'], Total Alarms:3
# [436]Source:47PAL600-ANN, Conditions:['ALM'], Total Alarms:3
# [437]Source:47PI2067, Conditions:['LO' 'LL' 'HI'], Total Alarms:3
# [438]Source:47PI2002, Conditions:['LO'], Total Alarms:2
# [439]Source:48PIC004, Conditions:['LL' 'LO'], Total Alarms:2
# [440]Source:47TI3313, Conditions:['LO'], Total Alarms:3
# [441]Source:47TI611, Conditions:['HI' 'HH'], Total Alarms:3
# [442]Source:47UALL802-ANN, Conditions:['ALM'], Total Alarms:3
# [443]Source:47UALL752-ANN, Conditions:['ALM'], Total Alarms:2
# [444]Source:47XL020-ANN, Conditions:['ALM'], Total Alarms:2
# [445]Source:48TI021, Conditions:['LO' 'LL'], Total Alarms:1
# [446]Source:47UALL702-ANN, Conditions:['ALM'], Total Alarms:2
# [447]Source:47TI2058A, Conditions:['HI'], Total Alarms:2
# [448]Source:47PALL757-ANN, Conditions:['ALM'], Total Alarms:2
# [449]Source:47FALL751-ANN, Conditions:['ALM'], Total Alarms:2
# [450]Source:47TIC274, Conditions:['LO' 'HI'], Total Alarms:2
# [451]Source:47UA717-ANN, Conditions:['ALM'], Total Alarms:2
# [452]Source:47LIC2001, Conditions:['LL' 'LO'], Total Alarms:1
# [453]Source:47UA703A-ANN, Conditions:['ALM'], Total Alarms:2
# [454]Source:47FIC033, Conditions:['HI' 'LO' 'LL'], Total Alarms:2
# [455]Source:47PI1707, Conditions:['LO'], Total Alarms:2
# [456]Source:47TI2058B, Conditions:['HI'], Total Alarms:2
# [457]Source:47XL3301A-ANN, Conditions:['ALM'], Total Alarms:2
# [458]Source:47XL3301B-ANN, Conditions:['ALM'], Total Alarms:2
# [459]Source:47XL017G-ANN, Conditions:['ALM'], Total Alarms:2
# [460]Source:47UAL751-ANN, Conditions:['ALM'], Total Alarms:2
# [461]Source:47AIC003, Conditions:['DV+' 'HH' 'HI'], Total Alarms:0
# [462]Source:47UA753A-ANN, Conditions:['ALM'], Total Alarms:2
# [463]Source:47UA767-ANN, Conditions:['ALM'], Total Alarms:2
# [464]Source:47XL019-ANN, Conditions:['ALM'], Total Alarms:2
# [465]Source:47TI1705, Conditions:['LO'], Total Alarms:1
# [466]Source:47XL017A-ANN, Conditions:['ALM'], Total Alarms:1
# [467]Source:47TIC009, Conditions:['MLO'], Total Alarms:2
# [468]Source:47UAL701-ANN, Conditions:['ALM'], Total Alarms:2
# [469]Source:47UA762-ANN, Conditions:['ALM'], Total Alarms:2
# [470]Source:47PAL758-ANN, Conditions:['ALM'], Total Alarms:2
# [471]Source:47FIC3513, Conditions:['LO' 'LL'], Total Alarms:2
# [472]Source:48TI037, Conditions:['LO'], Total Alarms:2
# [473]Source:47PI800, Conditions:['LTRP' 'LLL'], Total Alarms:2
# [474]Source:47TIC937E, Conditions:['LO'], Total Alarms:2
# [475]Source:47PALL807-ANN, Conditions:['ALM'], Total Alarms:2
# [476]Source:47XL1531-ANN, Conditions:['ALM'], Total Alarms:2
# [477]Source:47TI864, Conditions:['HI'], Total Alarms:2
# [478]Source:47PDAH605-ANN, Conditions:['ALM'], Total Alarms:2
# [479]Source:47LI026C, Conditions:['HHH' 'HTRP'], Total Alarms:2
# [480]Source:47HID-020H-ANN, Conditions:['ALM'], Total Alarms:2
# [481]Source:47LI026B, Conditions:['HTRP' 'HHH'], Total Alarms:2
# [482]Source:47PI123ABC, Conditions:['LTRP' 'LLL'], Total Alarms:2
# [483]Source:47TI015ABC, Conditions:['HHH' 'HTRP'], Total Alarms:2
# [484]Source:47LI012, Conditions:['HI'], Total Alarms:2
# [485]Source:47XL017B-ANN, Conditions:['ALM'], Total Alarms:2
# [486]Source:48TI015, Conditions:['HI' 'LL' 'LO'], Total Alarms:1
# [487]Source:47LIC1511, Conditions:['HI'], Total Alarms:1
# [488]Source:47XL1526B-ANN, Conditions:['ALM'], Total Alarms:1
# [489]Source:47LI026A, Conditions:['HTRP' 'HHH'], Total Alarms:2
# [490]Source:47TI414O, Conditions:['HI'], Total Alarms:2
# [491]Source:47G108C-RUN-ANN, Conditions:['ALM'], Total Alarms:1
# [492]Source:47PAL808-ANN, Conditions:['ALM'], Total Alarms:2
# [493]Source:47TI854, Conditions:['HI'], Total Alarms:2
# [494]Source:48HSI-001, Conditions:['IOP' 'CNF'], Total Alarms:2
# [495]Source:47TIC413, Conditions:['LO'], Total Alarms:1
# [496]Source:47PAL812-ANN, Conditions:['ALM'], Total Alarms:2
# [497]Source:47TI1583, Conditions:['HI' 'HH'], Total Alarms:2
# [498]Source:47LALL3616-ANN, Conditions:['ALM'], Total Alarms:1
# [499]Source:47TI414C, Conditions:['LO'], Total Alarms:1
# [500]Source:47TAHH703A-ANN, Conditions:['ALM'], Total Alarms:2
# [501]Source:47LI1557B, Conditions:['HHH'], Total Alarms:2
# [502]Source:47EM304D-ANN, Conditions:['ALM'], Total Alarms:1
# [503]Source:47K2ACND11, Conditions:['ALM'], Total Alarms:1
# [504]Source:47AIC1503, Conditions:['HH' 'HI'], Total Alarms:2
# [505]Source:47UA753D-ANN, Conditions:['ALM'], Total Alarms:2
# [506]Source:19ZAL119A-ANN, Conditions:['ALM'], Total Alarms:2
# [507]Source:47TI428, Conditions:['HHH'], Total Alarms:2
# [508]Source:47TI2101, Conditions:['HH' 'HI'], Total Alarms:2
# [509]Source:47PI3639, Conditions:['LO'], Total Alarms:1
# [510]Source:48FALL027-ANN, Conditions:['ALM'], Total Alarms:2
# [511]Source:48UA012-ANN, Conditions:['ALM'], Total Alarms:1
# [512]Source:47TI1584, Conditions:['HH' 'HI'], Total Alarms:2
# [513]Source:47PI055, Conditions:['LL' 'LO'], Total Alarms:2
# [514]Source:47LIC3404, Conditions:['HH' 'HI'], Total Alarms:2
# [515]Source:47PDAHH625-ANN, Conditions:['ALM'], Total Alarms:2
# [516]Source:47FLI-033, Conditions:['CNF' 'IOP'], Total Alarms:2
# [517]Source:48FI006B, Conditions:['LTRP' 'LLL'], Total Alarms:1
# [518]Source:47FI1503D, Conditions:['LLL'], Total Alarms:2
# [519]Source:47TI485, Conditions:['HHH'], Total Alarms:2
# [520]Source:47TI422, Conditions:['HHH'], Total Alarms:2
# [521]Source:47HCD-046H-ANN, Conditions:['ALM'], Total Alarms:2
# [522]Source:47FI033D, Conditions:['LLL'], Total Alarms:2
# [523]Source:47PI2148A, Conditions:['HHH'], Total Alarms:2
# [524]Source:47HCD-047HH-ANN, Conditions:['ALM'], Total Alarms:2
# [525]Source:47UAL801-ANN, Conditions:['ALM'], Total Alarms:2
# [526]Source:47TI618, Conditions:['HI'], Total Alarms:2
# [527]Source:47PIC1560, Conditions:['HI' 'HH'], Total Alarms:2
# [528]Source:47FIC3102, Conditions:['LL' 'LO'], Total Alarms:2
# [529]Source:47TI487B, Conditions:['HHH'], Total Alarms:2
# [530]Source:47TI2057A, Conditions:['HI'], Total Alarms:2
# [531]Source:47TI946I, Conditions:['HHH'], Total Alarms:2
# [532]Source:47LI3104ABC, Conditions:['LTRP' 'LLL'], Total Alarms:2
# [533]Source:47XL2018A-ANN, Conditions:['ALM'], Total Alarms:2
# [534]Source:47UA812-ANN, Conditions:['ALM'], Total Alarms:1
# [535]Source:47UA703D-ANN, Conditions:['ALM'], Total Alarms:1
# [536]Source:47PIC3640, Conditions:['HI' 'LO'], Total Alarms:1
# [537]Source:48TIC038, Conditions:['LO'], Total Alarms:1
# [538]Source:47TIC2050, Conditions:['LL' 'LO'], Total Alarms:0
# [539]Source:47PAL704-ANN, Conditions:['ALM'], Total Alarms:1
# [540]Source:48TI031, Conditions:['LL' 'LO'], Total Alarms:0
# [541]Source:47K2BCND11, Conditions:['ALM'], Total Alarms:1
# [542]Source:47PAL700-ANN, Conditions:['ALM'], Total Alarms:1
# [543]Source:01XA048-ANN, Conditions:['ALM'], Total Alarms:1
# [544]Source:47EM304B-ANN, Conditions:['ALM'], Total Alarms:1
# [545]Source:47XL1533B-ANN, Conditions:['ALM'], Total Alarms:1
# [546]Source:47XL1534-ANN, Conditions:['ALM'], Total Alarms:1
# [547]Source:47PAL712-ANN, Conditions:['ALM'], Total Alarms:1
# [548]Source:48TI025, Conditions:['LL' 'LO'], Total Alarms:0
# [549]Source:19ZAH119A-ANN, Conditions:['ALM'], Total Alarms:0
# [550]Source:47PI063, Conditions:['LO'], Total Alarms:1
# [551]Source:48TI035, Conditions:['LO' 'LL'], Total Alarms:0
# [552]Source:47XL1557D-ANN, Conditions:['ALM'], Total Alarms:0
# [553]Source:47PAL2026-ANN, Conditions:['ALM'], Total Alarms:1
# [554]Source:47XL2018B-ANN, Conditions:['ALM'], Total Alarms:0
# [555]Source:47GC2010-20, Conditions:['IOP'], Total Alarms:0
# [556]Source:47FI1502BCD, Conditions:['LLL' 'LTRP'], Total Alarms:0
# [557]Source:47PAL804-ANN, Conditions:['ALM'], Total Alarms:1
# [558]Source:47TI944I, Conditions:['HHH'], Total Alarms:1
# [559]Source:47TI860, Conditions:['HI'], Total Alarms:1
# [560]Source:48TI029, Conditions:['LL' 'LO'], Total Alarms:0
# [561]Source:47GC2010-12, Conditions:['IOP'], Total Alarms:0
# [562]Source:48FIC009, Conditions:['HI'], Total Alarms:1
# [563]Source:47GC2010-16, Conditions:['IOP'], Total Alarms:0
# [564]Source:47GC2010-17, Conditions:['IOP'], Total Alarms:0
# [565]Source:47FI2011, Conditions:['LO' 'LL'], Total Alarms:0
# [566]Source:47XL1560-ANN, Conditions:['ALM'], Total Alarms:1
# [567]Source:47FI1505BCD, Conditions:['LTRP' 'LLL'], Total Alarms:0
# [568]Source:47GC2010-24, Conditions:['IOP'], Total Alarms:0
# [569]Source:47FI2030, Conditions:['HI'], Total Alarms:1
# [570]Source:47XL1510-ANN, Conditions:['ALM'], Total Alarms:1
# [571]Source:47XL603-ANN, Conditions:['ALM'], Total Alarms:1
# [572]Source:47PAH012-ANN, Conditions:['ALM'], Total Alarms:0
# [573]Source:47FIC1512, Conditions:['DV+'], Total Alarms:1
# [574]Source:47GC2010-13, Conditions:['IOP'], Total Alarms:0
# [575]Source:47PI2065, Conditions:['LO'], Total Alarms:1
# [576]Source:47XL1520-ANN, Conditions:['ALM'], Total Alarms:0
# [577]Source:48TI026, Conditions:['LL' 'LO'], Total Alarms:0
# [578]Source:47GC2010-15, Conditions:['IOP'], Total Alarms:0
# [579]Source:47FI3307, Conditions:['LO'], Total Alarms:1
# [580]Source:47LIC2012, Conditions:['LO'], Total Alarms:1
# [581]Source:47XL012-ANN, Conditions:['ALM'], Total Alarms:0
# [582]Source:47GC2010-23, Conditions:['IOP'], Total Alarms:0
# [583]Source:47XL601-ANN, Conditions:['ALM'], Total Alarms:1
# [584]Source:47GM205A-ANN, Conditions:['ALM'], Total Alarms:0
# [585]Source:47PI1701, Conditions:['HI'], Total Alarms:1
# [586]Source:47FD-035H-ANN, Conditions:['ALM'], Total Alarms:1
# [587]Source:47FD-069H-ANN, Conditions:['ALM'], Total Alarms:1
# [588]Source:47PIC2028, Conditions:['HI'], Total Alarms:1
# [589]Source:48PI073, Conditions:['LL'], Total Alarms:0
# [590]Source:47LI951, Conditions:['LO'], Total Alarms:1
# [591]Source:47TI803D, Conditions:['LO'], Total Alarms:1
# [592]Source:47PI2144ABC, Conditions:['LLL' 'LTRP'], Total Alarms:0
# [593]Source:47GC2010-9, Conditions:['IOP'], Total Alarms:0
# [594]Source:47TI800A, Conditions:['LO'], Total Alarms:1
# [595]Source:47FALL700-ANN, Conditions:['ALM'], Total Alarms:0
# [596]Source:47XL3607-ANN, Conditions:['ALM'], Total Alarms:0
# [597]Source:47PI2151ABC, Conditions:['HHH'], Total Alarms:1
# [598]Source:47FALL801-ANN, Conditions:['ALM'], Total Alarms:1
# [599]Source:47HCD-046HH-ANN, Conditions:['ALM'], Total Alarms:1
# [600]Source:47TI936I, Conditions:['HHH'], Total Alarms:1
# [601]Source:47K2C-CIUENB-ANN, Conditions:['ALM'], Total Alarms:1
# [602]Source:48LALL005X-ANN, Conditions:['ALM'], Total Alarms:1
# [603]Source:47XL017H-ANN, Conditions:['ALM'], Total Alarms:1
# [604]Source:47PI2151B, Conditions:['HHH'], Total Alarms:1
# [605]Source:48LAHH001X-ANN, Conditions:['ALM'], Total Alarms:1
# [606]Source:48FIX2040, Conditions:['IOP-'], Total Alarms:1
# [607]Source:47GC2010-6, Conditions:['IOP'], Total Alarms:0
# [608]Source:47GC2010-19, Conditions:['IOP'], Total Alarms:0
# [609]Source:47FI1503BCD, Conditions:['LLL' 'LTRP'], Total Alarms:0
# [610]Source:48FI002A, Conditions:['LTRP' 'LLL'], Total Alarms:0
# [611]Source:47PI2145ABC, Conditions:['LTRP' 'LLL'], Total Alarms:0
# [612]Source:47FI1504BCD, Conditions:['LLL' 'LTRP'], Total Alarms:0
# [613]Source:47PI2029ABC, Conditions:['LTRP' 'LLL'], Total Alarms:0
# [614]Source:48FFIC005, Conditions:['LO' 'LL'], Total Alarms:0
# [615]Source:47PDAH619-ANN, Conditions:['ALM'], Total Alarms:1
# [616]Source:47PI2034ABC, Conditions:['LLL' 'LTRP'], Total Alarms:0
# [617]Source:48FI006A, Conditions:['LTRP' 'LLL'], Total Alarms:0
# [618]Source:47TI800B, Conditions:['LO'], Total Alarms:1
# [619]Source:47FIC1544, Conditions:['DV-'], Total Alarms:1
# [620]Source:47XL017F-ANN, Conditions:['ALM'], Total Alarms:0
# [621]Source:47PI626, Conditions:['LO'], Total Alarms:1
# [622]Source:47TI803C, Conditions:['LO'], Total Alarms:1
# [623]Source:47UA817-ANN, Conditions:['ALM'], Total Alarms:1
# [624]Source:47GC2010-21, Conditions:['IOP'], Total Alarms:0
# [625]Source:47TI3311, Conditions:['LO'], Total Alarms:1
# [626]Source:47TI1570, Conditions:['LO'], Total Alarms:1
# [627]Source:47GC2010-25, Conditions:['IOP'], Total Alarms:0
# [628]Source:47TI1728, Conditions:['HH'], Total Alarms:1
# [629]Source:47PAL800-ANN, Conditions:['ALM'], Total Alarms:1
# [630]Source:47XL021-ANN, Conditions:['ALM'], Total Alarms:0
# [631]Source:47GC2010-10, Conditions:['IOP'], Total Alarms:0
# [632]Source:47UA803B-ANN, Conditions:['ALM'], Total Alarms:0
# [633]Source:47XL011-ANN, Conditions:['ALM'], Total Alarms:1
# [634]Source:48HSD-004H-ANN, Conditions:['ALM'], Total Alarms:1
# [635]Source:47TI803A, Conditions:['LO'], Total Alarms:1
# [636]Source:47XL600-ANN, Conditions:['ALM'], Total Alarms:0
# [637]Source:47TI600, Conditions:['HI'], Total Alarms:1
# [638]Source:47FIC2008, Conditions:['DV-'], Total Alarms:1
# [639]Source:47GC2010-14, Conditions:['IOP'], Total Alarms:0
# [640]Source:48TI035A, Conditions:['HHH'], Total Alarms:1
# [641]Source:47XL605-ANN, Conditions:['ALM'], Total Alarms:1
# [642]Source:47UA803A-ANN, Conditions:['ALM'], Total Alarms:1
# [643]Source:47TI807, Conditions:['LO'], Total Alarms:1
# [644]Source:47PDI809, Conditions:['HI'], Total Alarms:1
# [645]Source:47TI934I, Conditions:['HHH'], Total Alarms:1
# [646]Source:47PI860, Conditions:['HI'], Total Alarms:0
# [647]Source:47PI634, Conditions:['IOP'], Total Alarms:1
# [648]Source:47PI2039ABC, Conditions:['LTRP' 'LLL'], Total Alarms:0
# [649]Source:47PI861, Conditions:['HI'], Total Alarms:0
# [650]Source:47PDAH625-ANN, Conditions:['ALM'], Total Alarms:1
# [651]Source:47HCD-044H-ANN, Conditions:['ALM'], Total Alarms:1
# [652]Source:47XS3206-ANN, Conditions:['ALM'], Total Alarms:0
# [653]Source:47TI2111ABC, Conditions:['LLL'], Total Alarms:0
# [654]Source:47GC2010-18, Conditions:['IOP'], Total Alarms:0
# [655]Source:47GC2010-11, Conditions:['IOP'], Total Alarms:0
# [656]Source:47XL1561-ANN, Conditions:['ALM'], Total Alarms:0
# [657]Source:47TI803B, Conditions:['LO'], Total Alarms:1
# [658]Source:47PDAHH619-ANN, Conditions:['ALM'], Total Alarms:1
# [659]Source:19PI119A, Conditions:['HI'], Total Alarms:1
# [660]Source:47FD-033F-ANN, Conditions:['ALM'], Total Alarms:1
# [661]Source:47GC2010-4, Conditions:['IOP'], Total Alarms:0
# [662]Source:48TIC2027, Conditions:['IOP-'], Total Alarms:1
# [663]Source:48FI013, Conditions:['LO' 'LL'], Total Alarms:0
# [664]Source:47TI2111B, Conditions:['LLL'], Total Alarms:0
# [665]Source:47ZI910, Conditions:['LL' 'LO'], Total Alarms:0
# [666]Source:47TI2072, Conditions:['HI'], Total Alarms:1
# [667]Source:47PI604, Conditions:['LLL'], Total Alarms:1
# [668]Source:47GC2010-8, Conditions:['IOP'], Total Alarms:0
# [669]Source:47PI2019, Conditions:['HI'], Total Alarms:1
# [670]Source:47GC2010-5, Conditions:['IOP'], Total Alarms:0
# [671]Source:47TI812, Conditions:['LO'], Total Alarms:1
# [672]Source:47GC2010-22, Conditions:['IOP'], Total Alarms:0
# [673]Source:47GC2010-7, Conditions:['IOP'], Total Alarms:0
# [674]Source:47PI636, Conditions:['HI'], Total Alarms:1
# [675]Source:47FIC1540, Conditions:['LO'], Total Alarms:0
# [676]Source:47XL607-ANN, Conditions:['ALM'], Total Alarms:0
# [677]Source:47TIC1511, Conditions:['HI'], Total Alarms:0
# [678]Source:48LALL005-ANN, Conditions:['ALM'], Total Alarms:0
# [679]Source:47XL606-ANN, Conditions:['ALM'], Total Alarms:0
# [680]Source:47FIC034, Conditions:['LO'], Total Alarms:0
# [681]Source:47FIC2013B, Conditions:['DV+'], Total Alarms:0
# [682]Source:47TI2055, Conditions:['LO'], Total Alarms:0
# [683]Source:47TI010, Conditions:['HI'], Total Alarms:0
# [684]Source:47TI017, Conditions:['LO'], Total Alarms:0
# [685]Source:47EM304A-ANN, Conditions:['ALM'], Total Alarms:0
# [686]Source:47TIC2050_N, Conditions:['LO'], Total Alarms:0
# [687]Source:47FI2011C, Conditions:['LLL'], Total Alarms:0
# [688]Source:47K2CCND11, Conditions:['ALM'], Total Alarms:0
# [689]Source:48TI036, Conditions:['LO'], Total Alarms:0
# [690]Source:47FIC2014A, Conditions:['LO'], Total Alarms:0
# [691]Source:48TI045, Conditions:['LO'], Total Alarms:0
# [692]Source:48FALL002-ANN, Conditions:['ALM'], Total Alarms:0
# [693]Source:47ZI857B, Conditions:['HI'], Total Alarms:0
# [694]Source:47FIC2014B, Conditions:['DV+'], Total Alarms:0
# [695]Source:47FI2011B, Conditions:['LLL'], Total Alarms:0
# [696]Source:47FIC010, Conditions:['LO'], Total Alarms:0
# [697]Source:47XL1539B-ANN, Conditions:['ALM'], Total Alarms:0
# [698]Source:47TIC2050_N_D, Conditions:['LO'], Total Alarms:0
# [699]Source:47FI2062, Conditions:['HI'], Total Alarms:0
# [700]Source:47FI2011BCD, Conditions:['LLL'], Total Alarms:0
# [701]Source:47XL010-ANN, Conditions:['ALM'], Total Alarms:0
# [702]Source:47EM306A-ANN, Conditions:['ALM'], Total Alarms:0
# [703]Source:48TIC024, Conditions:['LL'], Total Alarms:0
# [704]Source:47XL1535-ANN, Conditions:['ALM'], Total Alarms:0
# [705]Source:47TI1536, Conditions:['LO'], Total Alarms:0
# [706]Source:47FIC017, Conditions:['HI'], Total Alarms:0
# [707]Source:48TI005, Conditions:['LO'], Total Alarms:0
# [708]Source:48FALL006-ANN, Conditions:['ALM'], Total Alarms:0
# [709]Source:47FI2011D, Conditions:['LLL'], Total Alarms:0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979769 entries, 0 to 979768
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   MachineName  979769 non-null  object
#  1   SourceName   979769 non-null  object
#  2   Message      979769 non-null  object
#  3   Condition    979769 non-null  object
#  4   MessageType  979769 non-null  object
#  5   StartTime    979769 non-null  datetime64[ns]
#  6   EndTime      979769 non-null  datetime64[ns]
#  7   EndMessage   979769 non-null  object
#  8   TimeDelta    979769 non-null  float64
#  9   Year-Month   979769 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(7)
# memory usage: 74.8+ MB
# >>Conversion from records to alarms is complete. Outputfile : ../.data/csvs/alarms/alarms_processed_2020_10.csv, Info : None

# %%
# alarm2 = CSV2Alarms(config)
# # df_alarms = alarm2.convertRecords2Alarms(df2)
# # df_alarms

# %%
def monthlyAlarms2SingleFile(alarms_dir, out_file_path ,cols):
    fps = [f for f in glob.glob(alarms_dir+ "*.csv")]
    print(f">> Files to process {fps}")
    dfs_list = []
    for f in fps:
        print(f">> === File: {f.split('/')[-1]}")
        df = pd.read_csv(f, usecols = cols ,parse_dates = ["StartTime","EndTime"])
        dfs_list.append(df)

    df = pd.concat(dfs_list, ignore_index=True)
    df.to_csv(out_file_path, index=False)
    return df


alarms_dir = "../.data/csvs/alarms/"
output_file = "../.data/all-months-alarms.csv"
cols = ["SourceName", "Condition","StartTime", "EndTime","TimeDelta","Year-Month"]

monthlyAlarms2SingleFile(alarms_dir=alarms_dir, out_file_path=output_file, cols=cols)
# Out:
# >> Files to process ['../.data/csvs/alarms/alarms_2019_3.csv', '../.data/csvs/alarms/alarms_processed_2020_9.csv', '../.data/csvs/alarms/alarms_2019_6.csv', '../.data/csvs/alarms/alarms_processed_2020_10.csv', '../.data/csvs/alarms/alarms_processed_2020_7.csv', '../.data/csvs/alarms/alarms_2020_03.csv', '../.data/csvs/alarms/alarms_processed_2020_11.csv', '../.data/csvs/alarms/alarms_2019_10.csv', '../.data/csvs/alarms/alarms_2019_4.csv', '../.data/csvs/alarms/alarms_2020_02.csv', '../.data/csvs/alarms/alarms_2019_11.csv', '../.data/csvs/alarms/alarms_2019_7.csv', '../.data/csvs/alarms/alarms_2019_8.csv', '../.data/csvs/alarms/alarms_2019_12.csv', '../.data/csvs/alarms/alarms_processed_2018.csv', '../.data/csvs/alarms/alarms_processed_2020_12.csv', '../.data/csvs/alarms/alarms_processed_2020_4.csv', '../.data/csvs/alarms/alarms_2020_01.csv', '../.data/csvs/alarms/alarms_processed_2020_6.csv', '../.data/csvs/alarms/alarms_2019_9.csv', '../.data/csvs/alarms/alarms_processed_2020_5.csv', '../.data/csvs/alarms/alarms_processed_2020_8.csv']
# >> === File: alarms_2019_3.csv
# >> === File: alarms_processed_2020_9.csv
# >> === File: alarms_2019_6.csv
# >> === File: alarms_processed_2020_10.csv
# >> === File: alarms_processed_2020_7.csv
# >> === File: alarms_2020_03.csv
# >> === File: alarms_processed_2020_11.csv
# >> === File: alarms_2019_10.csv
# >> === File: alarms_2019_4.csv
# >> === File: alarms_2020_02.csv
# >> === File: alarms_2019_11.csv
# >> === File: alarms_2019_7.csv
# >> === File: alarms_2019_8.csv
# >> === File: alarms_2019_12.csv
# >> === File: alarms_processed_2018.csv
# >> === File: alarms_processed_2020_12.csv
# >> === File: alarms_processed_2020_4.csv
# >> === File: alarms_2020_01.csv
# >> === File: alarms_processed_2020_6.csv
# >> === File: alarms_2019_9.csv
# >> === File: alarms_processed_2020_5.csv
# >> === File: alarms_processed_2020_8.csv
#                SourceName Condition           StartTime             EndTime  \
# 0                47TI931A       IOP 2019-03-06 13:19:17 2019-03-06 13:19:33
# 1                47TI931A       IOP 2019-03-06 13:19:35 2019-03-06 13:20:22
# 2                47TI931A       IOP 2019-03-06 13:20:24 2019-03-06 13:20:28
# 3                47TI931A       IOP 2019-03-06 13:20:30 2019-03-06 13:20:49
# 4                47TI931A       IOP 2019-03-06 13:20:51 2019-03-06 13:21:03
# ...                   ...       ...                 ...                 ...
# 23435875   47HCD-046H-ANN       ALM 2020-08-20 08:58:39 2020-08-20 09:02:07
# 23435876          47LI951        LO 2020-08-12 22:51:27 2020-08-13 15:46:05
# 23435877    47XL1525A-ANN       ALM 2020-08-22 11:40:12 2020-08-22 11:41:22
# 23435878        47FIC2026        LO 2020-08-21 11:50:10 2020-08-21 11:50:38
# 23435879  47HSD-050HH-ANN       ALM 2020-08-20 09:10:42 2020-08-20 09:27:19
#
#           TimeDelta Year-Month
# 0              16.0  (2019, 3)
# 1              47.0  (2019, 3)
# 2               4.0  (2019, 3)
# 3              19.0  (2019, 3)
# 4              12.0  (2019, 3)
# ...             ...        ...
# 23435875      208.0  (2020, 8)
# 23435876    60878.0  (2020, 8)
# 23435877       70.0  (2020, 8)
# 23435878       28.0  (2020, 8)
# 23435879      997.0  (2020, 8)
#
# [23435880 rows x 6 columns]
